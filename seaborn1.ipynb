# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# lineplot

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=df,ci=None)
plt.show()
# Out:
# /tmp/ipython-input-2820613985.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='sepal_length',y='sepal_width',data=df,ci=None)

# %% [markdown]
# confidence interval provide us wth a way to estimate a population parameter. rather than say that the parametre is equakt to e

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=df,hue='species',ci=None)
plt.show()
# Out:
# /tmp/ipython-input-3608284584.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='sepal_length',y='sepal_width',data=df,hue='species',ci=None)

# %%
sns.lineplot(x='sepal_length',y='species',data=df,hue='species',ci=None)
print(df.groupby('species')['sepal length'].max())
plt.show()
# Out:
# /tmp/ipython-input-3241195682.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='sepal_length',y='species',data=df,hue='species',ci=None)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3241195682.py in <cell line: 0>()
#       1 sns.lineplot(x='sepal_length',y='species',data=df,hue='species',ci=None)
# ----> 2 print(df.groupby('species')['sepal length'].max())
#       3 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
# ...

# %%
sns.lineplot(x='petal_length',y='species',hue='species', data=df, ci=None)
plt.show()

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df)
plt.title("scatter plot")
plt.show()

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df,hue='species')
plt.title("scatter plot")
plt.show()

# %%
#barplot
sns.barplot(x='species',y='sepal_length', data=df)
plt.show()

# %%
#countplot
sns.countplot(x='species',data=df,)
plt.show()

# %%
df

# %%
df.species.value_counts()

# %%
df.describe()

# %%
#box plot
sns.boxplot()x='sepal_width',data=df)
plt.show()

# %%
sns.pairplot(data=df,hue='species')
plt.show()

# %%
sns.catplot(x='sepal_length',data=df,kind="box")
plt.show()

# %%
sns.catplot(x='species',y='sepal_length',data=df,hue="box")
plt.show()

# %%
#heat map
sns.heatmap(df.drop("species",axis=1).corr(),annot=True)
